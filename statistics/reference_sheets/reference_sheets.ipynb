# %%
from helper_functions import print_all_images
print_all_images('images')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from helper_functions import print_all_images
#       2 print_all_images('images')
#
# ImportError: cannot import name 'print_all_images' from 'helper_functions' (/Users/mr.leaf/GitHub/notes-statistics-and-ai/statistics/reference_sheets/helper_functions.py)
