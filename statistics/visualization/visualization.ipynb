# %% [markdown]
# [<< home](../home.md)

# %% [markdown]
# # visualization

# %% [markdown]
# - [10 types of data visualization made simple](https://boostlabs.com/10-types-of-data-visualization-tools/)

# %% [markdown]
# - Column Chart
# - Bar Graph
# - Stacked Bar Graph
# - Stacked Column Chart
# - Area Chart
# - Dual Axis Chart
# - Line Graph
# - Mekko Chart
# - Pie Chart
# - Waterfall Chart
# - Bubble Chart
# - Scatter Plot Chart
# - Bullet Graph
# - Funnel Chart
# - Heat Map

# %% [markdown]
# ## useful reference images

# %%
import os
import matplotlib.pyplot as plt

def print_image(image_path):
    image = plt.imread(image_path)
    # Display the image
    plt.imshow(image)
    plt.axis('off')  # This line removes the axis with numbers around the image
    plt.show()

img_dir = "images/"
images = sorted(os.listdir(img_dir))
print(images)
print('')
for image_path in images:
    print(img_dir + image_path)
    print_image(img_dir + image_path)
# Out:
# ['1.10-types-of-data-visualization-1-1024x614.jpg', '2.matrix_scatter_plot.png']
#
# images/1.10-types-of-data-visualization-1-1024x614.jpg
# images/2.matrix_scatter_plot.png
