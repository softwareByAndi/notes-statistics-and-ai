# %% [markdown]
# [<< shape](../index.md)

# %% [markdown]
# # skewness

# %% [markdown]
# ### helpful reference images

# %%
from helper_functions import print_all_images
print_all_images('images/')
# Out:
# ['images/00.skewness.png', 'images/01.skew_compare_central_tendencies.png', 'images/2.boxplot_represntation_of_skewness.png', 'images/3.skewness_equations.png']
#
# image_path:  images/00.skewness.png
# image_path:  images/01.skew_compare_central_tendencies.png
# image_path:  images/2.boxplot_represntation_of_skewness.png
# image_path:  images/3.skewness_equations.png
