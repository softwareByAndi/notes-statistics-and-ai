# %%
sorted([2, 4, 4, 3, 8, 67, 23])
# Out:
# [2, 3, 4, 4, 8, 23, 67]

# %%
spade = 13/52
king = 4/52
spade_and_king = 1/52

# are spade and king independent?
# P(spade and king) = P(spade) * P(king)

spade * king == spade_and_king
# Out:
# True

# %%
20/120
# Out:
# 0.16666666666666666
